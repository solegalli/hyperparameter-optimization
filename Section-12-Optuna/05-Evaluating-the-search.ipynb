# %% [markdown]
# ## Search Analysis with Optuna
#
# In this notebook, I will demo the built-in plotting functions from Optuna.
#
# We will use the [matplotlib backend](https://optuna.readthedocs.io/en/stable/reference/visualization/matplotlib/index.html#module-optuna.visualization.matplotlib). Optuna also offers the functions with [plotly backend](https://optuna.readthedocs.io/en/stable/reference/visualization/index.html).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import optuna

# %% [markdown]
# ## Load the search results
#
# We created and stored this search in the previous notebook.

# %%
study_name = "cnn_study"  # Unique identifier of the study.
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(
    study_name=study_name,
    storage=storage_name,
)

# %%
study.best_params
# Out:
# {'num_conv_layers': 2,
#  'filters': 16,
#  'kernel_size': 5,
#  'strides': 1,
#  'activation': 'relu',
#  'num_dense_layers': 3,
#  'units': 364,
#  'optimizer_name': 'Adam',
#  'learning_rate': 0.005232847515447734}

# %% [markdown]
# ## Optimization history

# %%
fig = optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\2278197192.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   fig = optuna.visualization.matplotlib.plot_optimization_history(study)

# %% [markdown]
# ## Contour plot - 2D plots

# %%
optuna.visualization.matplotlib.plot_contour(
    study,
    params=["num_conv_layers", "num_dense_layers", "optimizer_name", 'units'],
)
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\3483989461.py:1: ExperimentalWarning: plot_contour is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_contour(
# [W 2024-09-20 15:42:18,851] Output figures of this Matplotlib-based `plot_contour` function would be different from those of the Plotly-based `plot_contour`.
# array([[<Axes: ylabel='num_conv_layers'>, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: ylabel='num_dense_layers'>, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: ylabel='optimizer_name'>, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: xlabel='num_conv_layers', ylabel='units'>,
#         <Axes: xlabel='num_dense_layers'>,
#         <Axes: xlabel='optimizer_name'>, <Axes: xlabel='units'>]],
#       dtype=object)

# %% [markdown]
# ## Plot slice

# %%
optuna.visualization.matplotlib.plot_slice(
    study,
    params=["num_conv_layers", "num_dense_layers", "optimizer_name", 'units'],
)
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\703580076.py:1: ExperimentalWarning: plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_slice(
# array([<Axes: xlabel='num_conv_layers', ylabel='Objective Value'>,
#        <Axes: xlabel='num_dense_layers'>, <Axes: xlabel='optimizer_name'>,
#        <Axes: xlabel='units'>], dtype=object)

# %% [markdown]
# ## Parameter importance
#
# fAnova by default but there are other methods. More details [here](https://optuna.readthedocs.io/en/stable/reference/importance.html)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\1036994904.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %% [markdown]
# ## Plot parallel coordinate
#
# Plots the high dimensional space of the search. In plain English, the feature combinations.

# %%
optuna.visualization.matplotlib.plot_parallel_coordinate(   
    study,
    params=["num_conv_layers", "num_dense_layers", "optimizer_name", 'units'],
)
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\2067141607.py:1: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_parallel_coordinate(
# <Axes: title={'center': 'Parallel Coordinate Plot'}>

# %% [markdown]
# ## Compare 2 or more searches

# %%
optuna.visualization.matplotlib.plot_edf([study])
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\2601326980.py:1: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_edf([study])
# <Axes: title={'center': 'Empirical Distribution Function Plot'}, xlabel='Objective Value', ylabel='Cumulative Probability'>

# %%
study_name2 = "cnn_study_2"
storage_name2 = "sqlite:///{}.db".format(study_name2)

study2 = optuna.load_study(
    study_name=study_name2,
    storage=storage_name2,
)

optuna.visualization.matplotlib.plot_edf([study, study2])
# Out:
# C:\Users\Sole\AppData\Local\Temp\ipykernel_2232\385476931.py:9: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_edf([study, study2])
# <Axes: title={'center': 'Empirical Distribution Function Plot'}, xlabel='Objective Value', ylabel='Cumulative Probability'>

# %% [markdown]
# ## More examples of visualizations
#
# https://optuna.readthedocs.io/en/stable/tutorial/10_key_features/005_visualization.html#
